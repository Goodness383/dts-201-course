# %%
ages = [19, 22, 21, 35, 28, 24, 31, 19, 27, 40]
re=sum(ages)
print ({re})
# Out:
# {266}

# %%
mn=re/len(ages)
print(mn)
# Out:
# 26.6

# %%
max(ages)
# Out:
# 40

# %%
min(ages)
# Out:
# 19

# %%
import statistics

# %%
median=statistics.median(ages)
print(median)
# Out:
# 25.5

# %%
# with a few extreme values pulling one of the numbers away from the centre
# it means there are outliers in the data distribution
